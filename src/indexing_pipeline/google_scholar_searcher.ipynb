# %%
import getpass
from serpapi import GoogleSearch

# %%
api_key = getpass.getpass()

# %%
def search_google_scholar_profiles(full_name:str):
    params = {
    "api_key": api_key,
    "engine": "google_scholar_profiles",
    "hl": "en",
    "mauthors": full_name
    }

    search = GoogleSearch(params)

    print("Searching for profile of ", full_name)
    results = search.get_dict()

    try:
        for profile in results["profiles"]:
            if "Ben Gurion University" in profile["affiliations"] or "Ben-Gurion University" in profile["affiliations"]:
                print(f"\tFound a profile of {profile['name']} under Ben Gurion Univerisity")
                return profile
    except KeyError as e:
        print(f"\tDid not find any profile of {full_name}. {e}")
    
    print(f"\tDid not find the profile of {full_name} under Ben Gurion university")

    return None

def get_author_uuid(profile:dict):
    return profile["author_id"]
        

def search_google_scholar_author(author_id):
    print(f"\tSearch for author id {author_id}")
    params = {
    "api_key": api_key,
    "engine": "google_scholar_author",
    "hl": "en",
    "author_id": author_id,
    "num": "100" # The maximum number
    }

    search = GoogleSearch(params)
    results = search.get_dict()

    return results

# %%
import json
import os 
supervisors_names = []

with open("../../data/supervisors.jsonl","r") as f:
    for line in f:
        supervisors_names.append(json.loads(line))

supervisors_names[:10]
# Out:
# [{'name': 'Jihad El sana',
#   'personal_website_url': ['https://www.cs.bgu.ac.il/~el-sana']},
#  {'name': 'Klara Kedem',
#   'personal_website_url': ['http://www.cs.bgu.ac.il/~klara']},
#  {'name': 'Matthew Katz',
#   'personal_website_url': ['https://www.cs.bgu.ac.il/~matya']},
#  {'name': 'Meirav Zehavi',
#   'personal_website_url': ['https://sites.google.com/site/zehavimeirav']},
#  {'name': 'Natan Rubin',
#   'personal_website_url': ['https://sites.google.com/site/natanrubinshomepage/']},
#  {'name': 'Paz Carmi',
#   'personal_website_url': ['https://www.cs.bgu.ac.il/~carmip']},
#  {'name': 'Ohad Ben-shahar',
#   'personal_website_url': ['https://www.cs.bgu.ac.il/~ben-shahar']},
#  {'name': 'Oren Freifeld',
#   'personal_website_url': ['https://www.cs.bgu.ac.il/~orenfr']},
#  {'name': 'Andrei Sharf',
#   'personal_website_url': ['https://www.cs.bgu.ac.il/~asharf']},
#  {'name': 'Danny Barash',
#   'personal_website_url': ['https://www.cs.bgu.ac.il/~dbarash']}]

# %%
save_path = "../../data/google_scholar/"

def search_supervisor(full_name,line_num):
    supervisor_path = os.path.join(save_path,f"{line_num}_{full_name}")

    if not os.path.exists(supervisor_path):
        os.makedirs(supervisor_path)
    
    profile = search_google_scholar_profiles(full_name)

    if profile is None:
        print(f"Did not find profile for {full_name}... break")
        return
    
    with open(os.path.join(supervisor_path,"profile.json"),"w") as f:
        json.dump(profile, f)
    
    author_id = get_author_uuid(profile)

    author_details = search_google_scholar_author(author_id)

    with open(os.path.join(supervisor_path,"author_details.json"),"w") as f:
        json.dump(author_details,f)

    if len(author_details["articles"]) < 100:
        print(f"\t Retreived {len(author_details["articles"])} articles")
    else:
        print("\t SerpAPI allows only 100 max articales at a time, YOU MIGHT NEED TO SCRAPE MORE")
        return 0
    
    return 1

# %%
# search_supervisor(supervisors_names[0]["name"],0)
# Out:
# Searching for profile of  Jihad El sana
# 	Found a profile of Jihad El-Sana under Ben Gurion Univerisity
# True

# %%
more_scraping = []
i_offset = 1
i_end = 5

for i,supervisor_dict in enumerate(supervisors_names[i_offset:i_end]):
    global_index = i_offset+i
    print(f"global_index is {global_index}")
    
    status = search_supervisor(supervisor_dict["name"],global_index) # i+1 because of supervisors_names[i_offset:] (to remain consistent)

    if status == 0:
        more_scraping.append(supervisor_dict)
# Out:
# global_index is 1
# Searching for profile of  Klara Kedem
# 	Found a profile of Klara Kedem under Ben Gurion Univerisity
# 	 SerpAPI allows only 100 max articales at a time, YOU MIGHT NEED TO SCRAPE MORE
# global_index is 2
# Searching for profile of  Matthew Katz
# 	Found a profile of Matthew J. Katz under Ben Gurion Univerisity
# 	 SerpAPI allows only 100 max articales at a time, YOU MIGHT NEED TO SCRAPE MORE
# global_index is 3
# Searching for profile of  Meirav Zehavi
# 	Found a profile of Meirav Zehavi under Ben Gurion Univerisity
# 	 SerpAPI allows only 100 max articales at a time, YOU MIGHT NEED TO SCRAPE MORE
# global_index is 4
# Searching for profile of  Natan Rubin
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 8
#       6 global_index = i_offset+i
#       7 print(f"global_index is {global_index}")
# ----> 8 status = search_supervisor(supervisor_dict["name"],global_index) # i+1 because of supervisors_names[i_offset:] (to remain consistent)
#      10 if status == 0:
#      11     more_scraping.append(supervisor_dict)
#
# Cell In[23], line 9, in search_supervisor(full_name, line_num)
#       6 if not os.path.exists(supervisor_path):
#       7     os.makedirs(supervisor_path)
# ----> 9 profile = search_google_scholar_profiles(full_name)
#      11 if profile is None:
#      12     print(f"Did not find profile for {full_name}... break")
#
# Cell In[3], line 14, in search_google_scholar_profiles(full_name)
#      11 print("Searching for profile of ", full_name)
#      12 results = search.get_dict()
# ---> 14 for profile in results["profiles"]:
#      15     if "Ben Gurion University" in profile["affiliations"] or "Ben-Gurion University" in profile["affiliations"]:
#      16         print(f"\tFound a profile of {profile['name']} under Ben Gurion Univerisity")
#
# KeyError: 'profiles'

# %%
more_scraping = []
i_offset = 5
i_end = 10

for i,supervisor_dict in enumerate(supervisors_names[i_offset:i_end]):
    global_index = i_offset+i
    print(f"global_index is {global_index}")
    
    try:
        status = search_supervisor(supervisor_dict["name"],global_index) # i+1 because of supervisors_names[i_offset:] (to remain consistent)

        if status == 0:
            more_scraping.append(supervisor_dict)
    except Exception as e:
        print(f"An error occured while searching for {supervisor_dict["name"]}. {e}")
# Out:
# global_index is 5
# Searching for profile of  Paz Carmi
# 	Found a profile of Paz Carmi under Ben Gurion Univerisity
# 	Search for author id 6YQQL84AAAAJ
# 	 SerpAPI allows only 100 max articales at a time, YOU MIGHT NEED TO SCRAPE MORE
# global_index is 6
# Searching for profile of  Ohad Ben-shahar
# 	Found a profile of Ohad Ben-Shahar under Ben Gurion Univerisity
# 	Search for author id t77PmuQAAAAJ
# 	 SerpAPI allows only 100 max articales at a time, YOU MIGHT NEED TO SCRAPE MORE
# global_index is 7
# Searching for profile of  Oren Freifeld
# 	Found a profile of Oren Freifeld under Ben Gurion Univerisity
# 	Search for author id fxzlm6IAAAAJ
# 	 Retreived 63 articles
# global_index is 8
# Searching for profile of  Andrei Sharf
# 	Found a profile of Andrei Sharf under Ben Gurion Univerisity
# 	Search for author id QMEZPXEAAAAJ
# 	 Retreived 83 articles
# global_index is 9
# Searching for profile of  Danny Barash
# 	Found a profile of Danny Barash under Ben Gurion Univerisity
# 	Search for author id PlEWwDQAAAAJ
# 	 SerpAPI allows only 100 max articales at a time, YOU MIGHT NEED TO SCRAPE MORE

# %%
more_scraping = []
i_offset = 10
i_end = 30

for i,supervisor_dict in enumerate(supervisors_names[i_offset:i_end]):
    global_index = i_offset+i
    print(f"global_index is {global_index}")
    
    try:
        status = search_supervisor(supervisor_dict["name"],global_index) # i+1 because of supervisors_names[i_offset:] (to remain consistent)

        if status == 0:
            more_scraping.append(supervisor_dict)
    except Exception as e:
        print(f"An error occured while searching for {supervisor_dict["name"]}. {e}")
# Out:
# global_index is 10
# Searching for profile of  Eran Treister
# 	Found a profile of Eran Treister under Ben Gurion Univerisity
# 	Search for author id 5nNoFlEAAAAJ
# 	 Retreived 72 articles
# global_index is 11
# Searching for profile of  Avraham Melkman
# 	Found a profile of Avraham Melkman under Ben Gurion Univerisity
# 	Search for author id BygRsi8AAAAJ
# 	 Retreived 53 articles
# global_index is 12
# Searching for profile of  Chen Keasar
# 	Found a profile of Chen keasar under Ben Gurion Univerisity
# 	Search for author id UgWH55gAAAAJ
# 	 Retreived 52 articles
# global_index is 13
# Searching for profile of  Michal Ziv-ukelson
# 	Found a profile of Michal Ziv-Ukelson under Ben Gurion Univerisity
# 	Search for author id Fp1QSKgAAAAJ
# 	 Retreived 75 articles
# global_index is 14
# Searching for profile of  Yefim Dinitz
# 	Did not find any profile of Yefim Dinitz. 'profiles'
# 	Did not find the profile of Yefim Dinitz under Ben Gurion university
# Did not find profile for Yefim Dinitz... break
# global_index is 15
# Searching for profile of  Eitan Bachmat
# 	Did not find the profile of Eitan Bachmat under Ben Gurion university
# Did not find profile for Eitan Bachmat... break
# global_index is 16
# Searching for profile of  Inbal rachel Livni navon
# 	Did not find any profile of Inbal rachel Livni navon. 'profiles'
# 	Did not find the profile of Inbal rachel Livni navon under Ben Gurion university
# Did not find profile for Inbal rachel Livni navon... break
# global_index is 17
# Searching for profile of  Miriam Balaban
# 	Did not find any profile of Miriam Balaban. 'profiles'
# 	Did not find the profile of Miriam Balaban under Ben Gurion university
# Did not find profile for Miriam Balaban... break
# global_index is 18
# Searching for profile of  Shlomi Dolev
# 	Found a profile of Shlomi Dolev under Ben Gurion Univerisity
# 	Search for author id Y_-5w7EAAAAJ
# 	 SerpAPI allows only 100 max articales at a time, YOU MIGHT NEED TO SCRAPE MORE
# global_index is 19
# Searching for profile of  David Tolpin
# 	Did not find the profile of David Tolpin under Ben Gurion university
# Did not find profile for David Tolpin... break
# global_index is 20
# Searching for profile of  Gera Weiss
# 	Found a profile of Gera Weiss under Ben Gurion Univerisity
# 	Search for author id T2KfbBYAAAAJ
# 	 SerpAPI allows only 100 max articales at a time, YOU MIGHT NEED TO SCRAPE MORE
# global_index is 21
# Searching for profile of  Omri Azencot
# 	Did not find the profile of Omri Azencot under Ben Gurion university
# Did not find profile for Omri Azencot... break
# global_index is 22
# Searching for profile of  Gil Einziger
# 	Found a profile of Gil Einziger under Ben Gurion Univerisity
# 	Search for author id kWivlnsAAAAJ
# 	 Retreived 89 articles
# global_index is 23
# Searching for profile of  Ehud Gudes
# 	Did not find any profile of Ehud Gudes. 'profiles'
# 	Did not find the profile of Ehud Gudes under Ben Gurion university
# Did not find profile for Ehud Gudes... break
# global_index is 24
# Searching for profile of  Yuval Moskovitch
# 	Found a profile of Yuval Moskovitch under Ben Gurion Univerisity
# 	Search for author id iBEZIwEAAAAJ
# 	 Retreived 39 articles
# global_index is 25
# Searching for profile of  Liron Cohen
# 	Found a profile of Liron Cohen under Ben Gurion Univerisity
# 	Search for author id D6F0-iUAAAAJ
# 	 Retreived 38 articles
# global_index is 26
# Searching for profile of  Mayer Goldberg
# 	Did not find any profile of Mayer Goldberg. 'profiles'
# 	Did not find the profile of Mayer Goldberg under Ben Gurion university
# Did not find profile for Mayer Goldberg... break
# global_index is 27
# Searching for profile of  Michael Codish
# 	Found a profile of Michael Codish under Ben Gurion Univerisity
# 	Search for author id w6rPFlcAAAAJ
# 	 SerpAPI allows only 100 max articales at a time, YOU MIGHT NEED TO SCRAPE MORE
# global_index is 28
# Searching for profile of  Dana Fisman
# 	Found a profile of Dana Fisman under Ben Gurion Univerisity
# 	Search for author id LWgGkRsAAAAJ
# 	 SerpAPI allows only 100 max articales at a time, YOU MIGHT NEED TO SCRAPE MORE
# global_index is 29
# Searching for profile of  Michael Elhadad
# 	Found a profile of Michael Elhadad under Ben Gurion Univerisity
# 	Search for author id Is0pLz0AAAAJ
# 	 SerpAPI allows only 100 max articales at a time, YOU MIGHT NEED TO SCRAPE MORE

# %%
more_scraping = []
i_offset = 30
i_end = 51

for i,supervisor_dict in enumerate(supervisors_names[i_offset:i_end]):
    global_index = i_offset+i
    print(f"global_index is {global_index}")
    
    try:
        status = search_supervisor(supervisor_dict["name"],global_index) # i+1 because of supervisors_names[i_offset:] (to remain consistent)

        if status == 0:
            more_scraping.append(supervisor_dict)
    except Exception as e:
        print(f"An error occured while searching for {supervisor_dict["name"]}. {e}")
# Out:
# global_index is 30
# Searching for profile of  Aryeh Kontorovich
# 	Found a profile of Aryeh Kontorovich under Ben Gurion Univerisity
# 	Search for author id UNVQ5DsAAAAJ
# 	 SerpAPI allows only 100 max articales at a time, YOU MIGHT NEED TO SCRAPE MORE
# global_index is 31
# Searching for profile of  Daniel Berend
# 	Found a profile of Daniel Berend under Ben Gurion Univerisity
# 	Search for author id k4zZo44AAAAJ
# 	 SerpAPI allows only 100 max articales at a time, YOU MIGHT NEED TO SCRAPE MORE
# global_index is 32
# Searching for profile of  Danny Hendler
# 	Found a profile of Danny Hendler under Ben Gurion Univerisity
# 	Search for author id Vz6nlzcAAAAJ
# 	 SerpAPI allows only 100 max articales at a time, YOU MIGHT NEED TO SCRAPE MORE
# global_index is 33
# Searching for profile of  Oded Margalit
# 	Did not find the profile of Oded Margalit under Ben Gurion university
# Did not find profile for Oded Margalit... break
# global_index is 34
# Searching for profile of  Ronen Brafman
# 	Found a profile of Ronen Brafman under Ben Gurion Univerisity
# 	Search for author id FRxsXjcAAAAJ
# 	 SerpAPI allows only 100 max articales at a time, YOU MIGHT NEED TO SCRAPE MORE
# global_index is 35
# Searching for profile of  Niv yehuda Gilboa
# 	Did not find any profile of Niv yehuda Gilboa. 'profiles'
# 	Did not find the profile of Niv yehuda Gilboa under Ben Gurion university
# Did not find profile for Niv yehuda Gilboa... break
# global_index is 36
# Searching for profile of  Or Sattath
# 	Found a profile of Or Sattath under Ben Gurion Univerisity
# 	Search for author id 8uIbB4YAAAAJ
# 	 Retreived 45 articles
# global_index is 37
# Searching for profile of  Itai Dinur
# 	Did not find any profile of Itai Dinur. 'profiles'
# 	Did not find the profile of Itai Dinur under Ben Gurion university
# Did not find profile for Itai Dinur... break
# global_index is 38
# Searching for profile of  Yuval Pinter
# 	Found a profile of Yuval Pinter under Ben Gurion Univerisity
# 	Search for author id aYAcXccAAAAJ
# 	 Retreived 58 articles
# global_index is 39
# Searching for profile of  Eyal shlomo Shimony
# 	Did not find any profile of Eyal shlomo Shimony. 'profiles'
# 	Did not find the profile of Eyal shlomo Shimony under Ben Gurion university
# Did not find profile for Eyal shlomo Shimony... break
# global_index is 40
# Searching for profile of  Amnon Meisels
# 	Found a profile of Amnon Meisels under Ben Gurion Univerisity
# 	Search for author id aT_8hAoAAAAJ
# 	 SerpAPI allows only 100 max articales at a time, YOU MIGHT NEED TO SCRAPE MORE
# global_index is 41
# Searching for profile of  Moshe Sipper
# 	Found a profile of Moshe Sipper under Ben Gurion Univerisity
# 	Search for author id k2xM7QgAAAAJ
# 	 SerpAPI allows only 100 max articales at a time, YOU MIGHT NEED TO SCRAPE MORE
# global_index is 42
# Searching for profile of  Itay Safran
# 	Found a profile of Itay Safran under Ben Gurion Univerisity
# 	Search for author id nzS2jrMAAAAJ
# 	 Retreived 14 articles
# global_index is 43
# Searching for profile of  Sivan Sabato
# 	Did not find the profile of Sivan Sabato under Ben Gurion university
# Did not find profile for Sivan Sabato... break
# global_index is 44
# Searching for profile of  Yehuda Dar
# 	Found a profile of Yehuda Dar under Ben Gurion Univerisity
# 	Search for author id lKeL2F4AAAAJ
# 	 Retreived 27 articles
# global_index is 45
# Searching for profile of  Sigal Oren
# 	Found a profile of Sigal Oren under Ben Gurion Univerisity
# 	Search for author id zgCFb84AAAAJ
# 	 Retreived 38 articles
# global_index is 46
# Searching for profile of  Amos Beimel
# 	Found a profile of Amos Beimel under Ben Gurion Univerisity
# 	Search for author id gDNJ_YwAAAAJ
# 	 Retreived 98 articles
# global_index is 47
# Searching for profile of  Dekel Tsur
# 	Found a profile of Dekel Tsur under Ben Gurion Univerisity
# 	Search for author id Rk1IR3wAAAAJ
# 	 Retreived 78 articles
# global_index is 48
# Searching for profile of  Eden Chlamtac
# 	Did not find any profile of Eden Chlamtac. 'profiles'
# 	Did not find the profile of Eden Chlamtac under Ben Gurion university
# Did not find profile for Eden Chlamtac... break
# global_index is 49
# Searching for profile of  Klim Efremenko
# 	Did not find the profile of Klim Efremenko under Ben Gurion university
# Did not find profile for Klim Efremenko... break
# global_index is 50
# Searching for profile of  Michael Elkin
# 	Found a profile of Michael Elkin under Ben Gurion Univerisity
# 	Search for author id bPZBS_gAAAAJ
# 	 SerpAPI allows only 100 max articales at a time, YOU MIGHT NEED TO SCRAPE MORE

# %%
more_scraping = []
i_offset = 51
i_end = 55

for i,supervisor_dict in enumerate(supervisors_names[i_offset:i_end]):
    global_index = i_offset+i
    print(f"global_index is {global_index}")
    
    try:
        status = search_supervisor(supervisor_dict["name"],global_index) # i+1 because of supervisors_names[i_offset:] (to remain consistent)

        if status == 0:
            more_scraping.append(supervisor_dict)
    except Exception as e:
        print(f"An error occured while searching for {supervisor_dict["name"]}. {e}")
# Out:
# global_index is 51
# Searching for profile of  Ofer Neiman
# 	Found a profile of Ofer Neiman under Ben Gurion Univerisity
# 	Search for author id oApOKYYAAAAJ
# 	 Retreived 72 articles
# global_index is 52
# Searching for profile of  Uri Stemmer
# 	Did not find the profile of Uri Stemmer under Ben Gurion university
# Did not find profile for Uri Stemmer... break
# global_index is 53
# Searching for profile of  Dean Doron
# 	Found a profile of Dean Doron under Ben Gurion Univerisity
# 	Search for author id IhJrO6cAAAAJ
# 	 Retreived 37 articles
# global_index is 54
# Searching for profile of  Jonathan Mosheiff
# 	Found a profile of Jonathan Mosheiff under Ben Gurion Univerisity
# 	Search for author id FvlR-H4AAAAJ
# An error occured while searching for Jonathan Mosheiff. 'articles'
